# %%
import pandas as pd

# To upload a file, run this cell. A file upload dialog will appear.
# Select 'orders.csv' from your local machine.
from google.colab import files
files.upload()

# Once uploaded, you can read the CSV file
df = pd.read_csv("orders.csv")

df.head()
# Out:
#      <input type="file" id="files-4ac9f243-31a3-48c5-8984-5e8ec003b01d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4ac9f243-31a3-48c5-8984-5e8ec003b01d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       20 non-null     int64
#  1   customer_name  20 non-null     object
#  2   product        20 non-null     object
#  3   quantity       16 non-null     float64
#  4   unit_price     20 non-null     float64
#  5   order_date     16 non-null     object
#  6   status         20 non-null     object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 1.2+ KB

# %%
df.isnull().sum()
# Out:
# order_id         0
# customer_name    0
# product          0
# quantity         4
# unit_price       0
# order_date       4
# status           0
# dtype: int64

# %%
df['order_date'] = pd.to_datetime(df['order_date'])

# %%
df.describe()
# Out:
#          order_id   quantity    unit_price           order_date
# count    20.00000  16.000000     20.000000                   16
# mean   1010.50000   2.437500  20224.600000  2024-01-24 09:00:00
# min    1001.00000   1.000000    499.000000  2024-01-15 00:00:00
# 25%    1005.75000   1.000000    799.000000  2024-01-19 18:00:00
# 50%    1010.50000   2.000000   2500.000000  2024-01-24 12:00:00
# 75%    1015.25000   3.000000  14625.000000  2024-01-29 06:00:00
# max    1020.00000   6.000000  85000.000000  2024-02-02 00:00:00
# std       5.91608   1.504161  33573.389607                  NaN
